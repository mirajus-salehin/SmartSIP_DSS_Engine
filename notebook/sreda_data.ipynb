# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../db/SREDA_data_2026_updated.csv")

# %%
sns.histplot(df["DC Capacity"], kde=True)
# Out:
# <Axes: xlabel='DC Capacity', ylabel='Count'>

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3556 entries, 0 to 3555
# Data columns (total 8 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   kid                                         3556 non-null   int64
#  1   DC Capacity                                 3556 non-null   float64
#  2   Implementing Agency or Responsible Utility  3556 non-null   str
#  3   Division                                    3556 non-null   str
#  4   District                                    3556 non-null   str
#  5   Upazilla                                    3556 non-null   str
#  6   Latitude                                    3556 non-null   float64
#  7   Longitude                                   3556 non-null   float64
# dtypes: float64(3), int64(1), str(4)
# memory usage: 494.9 KB
